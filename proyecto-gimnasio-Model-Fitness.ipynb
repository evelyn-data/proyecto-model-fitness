# %% [markdown]
# # Hola Evelyn!
#
# Mi nombre es David Bautista, soy code reviewer de TripleTen y voy a revisar el proyecto que acabas de desarrollar.
#
# Cuando vea un error la primera vez, lo señalaré. Deberás encontrarlo y arreglarlo. La intención es que te prepares para un espacio real de trabajo. En un trabajo, el líder de tu equipo hará lo mismo. Si no puedes solucionar el error, te daré más información en la próxima ocasión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres.**
#
# ¿Cómo lo voy a hacer? Voy a leer detenidamente cada una de las implementaciones que has llevado a cabo para cumplir con lo solicitado. Verás los comentarios de esta forma:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si todo está perfecto.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
#
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
#
# Puedes responderme de esta forma:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
# </div>
#
# ¡Empecemos!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# # Comentario General
#
# ~~Hola Evelyn, te felicito por el desarrollo del proyecto hasta el momento. Ahora bien, he dejado algunos comentarios para que los puedas tener en cuenta para la sigiente entrega.~~  </div>
#
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# # Comentario General #2
#
# Hola Evelyn, te felicito por la culminación del proyecto. Muy buen trabajo.  </div>

# %% [markdown]
# # Proyecto 13

# %% [markdown]
# ## Descripción del proyecto
#
# La cadena de gimnasios Model Fitness está desarrollando una estrategia de interacción con clientes basada en datos analíticos.
#
# Uno de los problemas más comunes que enfrentan los gimnasios y otros servicios es la pérdida de clientes. ¿Cómo descubres si un/a cliente ya no está contigo?
#
# En el caso de un gimnasio, tiene sentido decir que un/a cliente se ha ido si no viene durante un mes. Por supuesto, es posible que estén en Cancún y retomen sus visitas cuando regresen, pero ese no es un caso típico. Por lo general, si un/a cliente se une, viene varias veces y luego desaparece, es poco probable que regrese.
#
# Con el fin de combatir la cancelación, Model Fitness ha digitalizado varios de sus perfiles de clientes. Tu tarea consiste en analizarlos y elaborar una estrategia de retención de clientes.

# %% [markdown]
# ## Descripción de datos
#
# **Model Fitness aportó archivos CSV que contienen los datos sobre la cancelación de un mes en concreto e información del mes que lo precedía.**
# El dataset incluye los siguientes campos:
#
#
# * `Churn` — la cancelación para el mes en cuestión
# * Campos de dataset actuales:
#     * Datos del usuario del mes anterior
#         * `gender`.
#         * `Near_Location` — si el/la usuario/a vive o trabaja en el vecindario donde se encuentra el gimnasio.
#         * `Partner` — si el/la usuario/a trabaja en una compañía asociada (el gimnasio tiene empresas asociadas cuyos empleados obtienen descuentos; en esos casos el gimnasio almacena información sobre los empleadores de los clientes).
#         * `Promo_friends` — si el/la usuario/a originalmente se inscribió mediante una oferta “trae a un/a amigo/a” (se utilizó el código promocional de un/a amigo/a cuando pagaron el primer abono).
#         * `Phone` — si el/la usuario/a aportó el número de teléfono.
#         * `Age`.
#         * `Lifetime` — el tiempo (en meses) desde que el/la usuario/a llegó por primera vez al gimnasio.
#
# Datos del registro de visitas y compras y datos sobre el estado actual de la membresía:
# * `Contract_period` — 1 mes, 3 meses, 6 meses o 1 año.
# * `Month_to_end_contract` — los meses que faltan hasta que expire el contrato.
# * `Group_visits` — si el/la usuario/a participa en sesiones grupales.
# * `Avg_class_frequency_total` — frecuencia media de visitas por semana a lo largo de la vida del cliente.
# * `Avg_class_frequency_current_month` — frecuencia media de visitas por semana durante el mes en curso.
# * `Avg_additional_charges_total` — cantidad total de dinero gastado en otros servicios del gimnasio: cafetería, productos deportivos, cosméticos, masajes, etc.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Hola Evelyn, buen trabajo con el desarrollo de esta primera sección de desarollo e introducción del proyecto.
# </div>

# %% [markdown]
# ### Importación de librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.linear_model import Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto, buen trabajo importando las librerías necesarias para el desarrollo del proyecto. </div>

# %% [markdown]
# ### Importación de datos

# %%
# Cargar los datos
data = pd.read_csv('https://practicum-content.s3.us-west-1.amazonaws.com/datasets/gym_churn_us.csv')

# Ver las primeras filas del DataFrame
display(data.head())
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen trabajo Evelyn, cargas y exploras los datos de buena manera.  </div>

# %% [markdown]
# ## Análisis exploratorio de datos (EDA)
#
# En este apartado buscamos crear un modelo de clasificación binaria para clientes donde la característica objetivo es la marcha del usuario o la usuaria el mes siguiente.

# %%
# Información general del DataFrame
display(data.info())

# Descripción estadística de los datos
display(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# **Observaciones**
#
# * No tenemos valores nulos
# * Los datos están listos para comenzar el análisis

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen trabajo con esta exploración inicial de los datos Evelyn.  </div>

# %% [markdown]
# ### Historigrama de los clientes que se quedan vs. los que se van

# %%
#Comparar las medias para clientes que se quedan vs los que se van
grouped_data = data.groupby('Churn').mean()
display(grouped_data)
# Out:
#          gender  Near_Location   Partner  Promo_friends     Phone  \
# Churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        Contract_period  Group_visits        Age  Avg_additional_charges_total  \
# Churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        Month_to_end_contract  Lifetime  Avg_class_frequency_total  \
# Churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        Avg_class_frequency_current_month
# Churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto, buen trabajo con el estudio de los valores medios de cada característica sujeta a que los individuos estén o no suscritos.   </div>

# %%
#Histogramas para las características divididas por la cancelación
for column in data.columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(data=data, x=column, hue='Churn', element='step', stat='density', common_norm=False)
    plt.title('Distribución de ' + column)
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto Evelyn, buen trabajo con el desarrollo de los histogramas de cada una de las características.   </div>

# %% [markdown]
# ### Matriz de correlación

# %%
#Matriz de correlación
corr_matrix = data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# **Observaciones**
#
# * Contract_period y Month_to_end_contract (0.97)
#
# Esta correlación dio un resultado alto y es muy lógico que mientras más largo el contrato de periodo, más meses se quedan hasta su finalización. Este resultado también nos podría indicar multicolinealidad si se usan como modelos predictivos.
#
# * Avg_class_frequency_total y Avg_class_frequency_current_month (0.95)
#
# Esta correlación también fue alta, lo que podría indicar que los clientes con una frecuencia alta de clases y la frecuencia de clases en el mes no cambian drásticamente a lo largo del tiempo, es decir los clientes mantienen sus hábitos y continúan haciéndolo.
#
# * Churn y Contract_period (-0.39), Month_to_end_contract (-0.38)
#
# Los clientes con contratos más largos y más meses hasta el final del contrato tienen menos probabilidades de abandonar (churn). Esto podría indicar que compromisos a largo plazo disminuyen la probabilidad de cancelación.
#
# * Churn y Avg_class_frequency_current_month (-0.41)
#
# Una correlación negativa que indica que cuanto más frecuentemente los clientes asisten a clases en el mes actual, menos probable es que abandonen el gimnasio. Podría indicar que la participación es un factor importante en la retención de los clientes a largo plazo.
#
# * Churn y Age (-0.40)
#
# La edad tiene una correlación negativa con la cancelación, lo que sugiere que los clientes más jóvenes tienden a abandonar el gimnasio con más frecuencia que los clientes mayores, esto podría explicarse a que las personas más jovenes tienen más cambios en cuanto a rutinas y menor estabilidad económica.
#
#
# * Churn y Lifetime (-0.44)
#
# Una correlación negativa considerable que indica que los clientes con más tiempo desde su inscripción son menos propensos a abandonar. Esto podría reflejar un mayor compromiso o satisfacción con el gimnasio a medida que pasa el tiempo.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen trabajo con el desarrollo de la matriz de correlación entre las características y así mismo mostrando esta información por medio del heatmap.  </div>

# %% [markdown]
# ## Construir un modelo para predecir la cancelación de los usuarios/as
#
# Crea un modelo de clasificación binaria para clientes donde la característica objetivo es la marcha del usuario o la usuaria el mes siguiente. Para ello dividiremos los datos en conjuntos de entrenamiento y validación utilizando la función train_test_split().
#
# Luego, entrenaremos el modelo en el set de entrenamiento con los siguientes métodos:
#  * regresión logística;
#  * bosque aleatorio.
#
# Por último, se evalúa la exactitud, precisión y recall para ambos modelos utilizando los datos de validación.

# %%
#Preparar los datos
X = data.drop(['Churn'], axis=1)
y = data['Churn']

#Dividir los datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

#Inicializar y entrenar Regresión Logística
log_reg = LogisticRegression(random_state=0)
log_reg.fit(X_train, y_train)

#entrenar modelo
log_reg.fit(X_train, y_train)

#utilizar el modelo entrenado para hacer previsiones
predictions = log_reg.predict(X_test)
probabilities = log_reg.predict_proba(X_test)[:,1]

#mostrar todas las métricas estudiadas
print('Métricas de regresión logística')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, predictions)))

#Inicializar y entrenar Random Forest
random_forest = RandomForestClassifier(random_state=0)
random_forest.fit(X_train, y_train)


#utilizar el modelo entrenado para hacer previsiones
forest_predictions = random_forest.predict(X_test)
forest_probabilities = random_forest.predict_proba(X_test)[:,1]

#mostrar todas las métricas
print()
print('Métricas del árbol de decisión')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, forest_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, forest_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, forest_predictions)))
# Out:
# /opt/conda/envs/python3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/envs/python3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# **Observaciones**
#
# Ambos modelos obtuvieron buenos resultados y similares en algunas métricas.
#
# **Accuracy**
#
# * El árbol de decisión tiene una ligera ventaja en términos de precisión, lo que indica que puede predecir correctamente una mayor proporción del total de casos.
#
# **Precision**
#
# * El árbol de decisión es ligeramente superior en este aspecto, lo que implica que es más fiable para predecir que un cliente dejará el gimnasio.
#
# **Recall**
#
# * El recall es el mismo para ambos modelos, lo que indica que ambos son igualmente efectivos en identificar a todos los clientes relevantes que están en riesgo de cancelar su membresía.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen trabajo, Eveleym. En este bloque de código anterior desarollas diferentes componentes, retomémoslos uno a uno:
#
# - Desarrollas de buena manera la separación de las características y los targets y así mismo creaste de manera correcta los sets de entrenamiento y testeo para el despliegue de los datos.
#
# - Despliegas y evalúas de manera correcta de la regresión logística.
#
# - Despliegas y evalúas de manera correcta el random forest.  </div>

# %% [markdown]
# ## Clústers de usuarios
#
# Este apartado se enfoca en identificar los clústeres de objetos (usuarios/as).

# %%
# Estandarizar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Clustering Jerárquico
linked = linkage(X_scaled, method='ward')
plt.figure(figsize=(15, 10))
dendrogram(linked)
plt.title('Dendrograma')
plt.axis('off')
plt.show()

# K-Means Clustering
kmeans = KMeans(n_clusters=5, random_state=0)
labels = kmeans.fit_predict(X_scaled)

# Añadir las etiquetas al DataFrame original para análisis
data['Cluster'] = labels

# Análisis de clúster
cluster_means = data.groupby('Cluster').mean()
display(cluster_means)

# Tasa de cancelación por clúster
churn_rate_by_cluster = data.groupby('Cluster')['Churn'].mean()
display(churn_rate_by_cluster)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ~~Buen trabajo, Eveleyn. Desarrollas de buena manera el dendrograma, lo único que veo que puedas mejorar es ocultar los ticks del eje x para obtener una salida más estética.~~   </div>
#
#
#
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ~~Buen trabajo con el desarrollo de la estandarización de los datos y la creación de los clústers. Ahora bien, podrías mejorar la forma en que estás presentado el estudio de los valores medios de las tablas, podrías usar ``display()`` en vez de ``print()`` para que la tabla se muestre de mejora manera..~~ </div>
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Estoy de acuerdo que los ejes x no es nada estético y hasta podría ser confuso, opté por ocultar las etiquetas con "plt.axis('off')", espero sea una buena solución.
#
# ¡Muchas gracias por los comentarios! Quedo pendiente a culquier otra correción o comentario.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# De acuerdo con tu solución Evelyn, buen trabajo y gacias por tener en cuenta los comentarios. </div>

# %% [markdown]
# **OBSERVACIONES**
#
# **Análisis de resultados por clúster**
#
# **Clúster 0**: Clientes muy leales con el período de contrato más largo (casi 12 meses), alta frecuencia de visitas y muy baja tasa de cancelación (2.2%). Este grupo parece ser el más valioso y comprometido.
#
# **Clúster 1**: La tasa de cancelación más alta (57.3%), contratos cortos, baja frecuencia de visitas al gimnasio y menores cargos adicionales. Es términos generales, este grupo parece estar menos comprometido y en mayor riesgo de abandono.
#
# **Clúster 2**: Frecuencia de visitas relativamente alta y contrato promedio más largo que el clúster 1, con una baja tasa de cancelación (9%). En términos generales, este grupo podría ser considerado moderadamente leal.
#
# **Clúster 3 y 4**: Tasas de cancelación intermedias (26.7% y 24.6%, respectivamente) con un compromiso moderado en términos de período de contrato y frecuencia de visitas.
#
# **Observaciones Clave**
#
# Compromiso y lealtad: Hay una clara correlación entre la longitud del contrato, la frecuencia de visitas y la lealtad (tasa de cancelación baja). Los clientes con contratos más largos y mayor frecuencia de visitas tienden a ser más leales.
#
# Riesgo de cancelación: El clúster 1 destaca como el grupo con mayor riesgo de cancelación, lo que sugiere que medidas específicas deberían enfocarse en este grupo para mejorar su retención.
#
# Oportunidades de engagement: Los clústeres con tasas de cancelación intermedias (3 y 4) podrían beneficiarse de estrategias de engagement que aumenten su frecuencia de visitas o los animen a participar en más actividades grupales, lo que podría aumentar su lealtad.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen trabajo Evelyn. </div>

# %% [markdown]
# ## Conclusiones y recomendaciones

# %% [markdown]
# Basado en el análisis de los datos del gimnasio, las correlaciones observadas, y las tendencias en la retención y cancelación de clientes, llegamos a los siguientes conclusiones y principios:
#
#
# Compromiso de larga duración reduce el Churn: Los clientes con contratos más largos y aquellos que han estado con el gimnasio por más tiempo tienden a tener tasas de churn más bajas. El clúster con contratos más largos y mayor frecuencia de visitas mostró la tasa de churn más baja. Esto confirma que los contratos a largo plazo son vitales para la retención.
#
# Frecuencia de visitas correlaciona con la lealtad: Una mayor frecuencia de visitas al gimnasio se asocia significativamente con una menor probabilidad de cancelación.
#
# Participación en las actividades del gimnasio reduce el churn: Clústeres con altas tasas de participación en actividades grupales o visitas frecuentes mostraron tasas de churn más bajas, indicando que la integración en la comunidad del gimnasio es crucial.
#
#
# **Recomendaciones basadas en los datos observados**
#
# * Personalización de la comunicación: Segmentar las comunicaciones y ofertas según las características del clúster puede ayudar a mejorar la retención. Por ejemplo, ofrecer incentivos específicos para la renovación de contratos para el clúster 1 o programas de referidos que podrían atraer a más amigos al gimnasio.
#
# * Mejorar la experiencia del cliente: Para los clústeres con tasas de cancelación más altas, investigar más a fondo por qué estos clientes están menos comprometidos. Encuestas de satisfacción y feedback pueden proporcionar datos cruciales.
#
# * Promociones y ofertas: Para clústeres como el 0, mantener su alta lealtad a través de programas VIP o beneficios exclusivos podría ser una estrategia efectiva.
#
# * Incentivar contratos a largo plazo: se podrían ofrecer descuentos y promociones para los clientes con un mayor grado de lealtad y compromiso, con el objetivo de aumentar el número de clientes comprometidos a largo plazo.
#
# * Utilizar los datos para predecir y prevenir el churn. Implementar herramientas de análisis de datos para identificar señales tempranas de churn potencial, como la disminución en la frecuencia de visitas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen trabajo con el desarrollo de las conclusiones. </div>
